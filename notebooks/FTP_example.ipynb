# %%
from utilities import constants
import ftplib

# %%
ftp = ftplib.FTP('ztp.krakow.pl')
ftp.login()
ftp.cwd('pliki-gtfs')
# Out:
# '250 CWD command successful.'

# %%
list(ftp.mlsd())
# Out:
# [('/',
#   {'type': 'pdir',
#    'size': '4096',
#    'modify': '20191206112432',
#    'create': '20200401104158',
#    'perm': 'el',
#    'unique': '9303U43AF055',
#    'unix.mode': '0755'}),
#  ('/pliki-gtfs',
#   {'type': 'cdir',
#    'size': '4096',
#    'modify': '20200210112023',
#    'create': '20200401104158',
#    'perm': 'el',
#    'unique': '9303U43AF09A',
#    'unix.mode': '0755'}),
#  ('GTFS_KRK_T.zip',
#   {'type': 'file',
#    'size': '1773360',
#    'modify': '20210208002450',
#    'create': '20210208002450',
#    'perm': '',
#    'unique': '9303U43A3D2E',
#    'unix.mode': '0644'}),
#  ('VehiclePositions_T.pb',
#   {'type': 'file',
#    'size': '10347',
#    'modify': '20210222211720',
#    'create': '20210222211720',
#    'perm': '',
#    'unique': '9303U43A3D55',
#    'unix.mode': '0644'}),
#  ('TripUpdates_T.pb',
#   {'type': 'file',
#    'size': '118499',
#    'modify': '20210222211719',
#    'create': '20210222211719',
#    'perm': '',
# ...

# %%
list(ftp.mlsd())[-1]
# Out:
# ---------------------------------------------------------------------------
# error_temp                                Traceback (most recent call last)
# <ipython-input-33-7c96cba8d42a> in <module>
# ----> 1 list(ftp.mlsd())[-1]
#
# /usr/lib/python3.8/ftplib.py in mlsd(self, path, facts)
#     577             cmd = "MLSD"
#     578         lines = []
# --> 579         self.retrlines(cmd, lines.append)
#     580         for line in lines:
#     581             facts_found, _, name = line.rstrip(CRLF).partition(' ')
#
# /usr/lib/python3.8/ftplib.py in retrlines(self, cmd, callback)
#     448         if callback is None:
#     449             callback = print_line
# --> 450         resp = self.sendcmd('TYPE A')
#     451         with self.transfercmd(cmd) as conn, \
#     452                  conn.makefile('r', encoding=self.encoding) as fp:
#
# /usr/lib/python3.8/ftplib.py in sendcmd(self, cmd)
#     273         '''Send a command and return the response.'''
# ...

# %%
try:
    raise NotImplemented('aaaaaa')
except Exception as eee:
    qq = eee

# %%
str(qq)
# Out:
# "'NotImplementedType' object is not callable"

# %%
import pathlib

# %%
from utilities.constants import RAW_METADATA_PATH

# %%
err = RAW_METADATA_PATH.joinpath('error_log.txt')

# %%
q = err.open('r')

# %%
lines = q.readlines()

# %%
lines
# Out:
# ['30/11/2020 15:27:50\t|\t426 Transfer aborted: Resource temporarily unavailable.\n',
#  '30/11/2020 15:30:48\t|\t426 Transfer aborted: Resource temporarily unavailable.\n',
#  '30/11/2020 17:49:25\t|\t\n',
#  '30/11/2020 20:21:25\t|\t\n',
#  '30/11/2020 21:08:51\t|\t426 Transfer aborted: Resource temporarily unavailable.\n',
#  '30/11/2020 21:29:52\t|\t426 Transfer aborted: Resource temporarily unavailable.\n',
#  '30/11/2020 21:31:22\t|\t426 Transfer aborted: Resource temporarily unavailable.\n',
#  '30/11/2020 23:44:25\t|\t\n',
#  '01/12/2020 01:45:55\t|\t\n',
#  '01/12/2020 04:35:52\t|\ttimed out\n',
#  '01/12/2020 04:37:56\t|\ttimed out\n',
#  '01/12/2020 04:40:00\t|\ttimed out\n',
#  '01/12/2020 04:42:04\t|\ttimed out\n',
#  '01/12/2020 04:44:08\t|\ttimed out\n',
#  '01/12/2020 04:46:13\t|\ttimed out\n',
#  '01/12/2020 05:28:31\t|\t426 Transfer aborted: Resource temporarily unavailable.\n',
#  '01/12/2020 06:58:29\t|\t426 Transfer aborted: Resource temporarily unavailable.\n',
# ...
